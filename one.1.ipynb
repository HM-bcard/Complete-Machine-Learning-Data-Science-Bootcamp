# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# markdown

# %% [markdown]
# # Importing tools:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
