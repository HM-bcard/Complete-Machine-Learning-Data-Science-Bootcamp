# %% [markdown]
# # A1

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # A2 main datatypes:

# %%
series = pd.Series(["BMW","Toyota","Honda"])

# %% [markdown]
# # A3 series display

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: str

# %%
colours = pd.Series(["Red","Blue","Green"])
colours
# Out:
# 0      Red
# 1     Blue
# 2    Green
# dtype: str

# %% [markdown]
# # A4 Dataframe:
#
# ## two dimensional

# %% [markdown]
# # A5 creating data frames out of two series:

# %%
car_data = pd.DataFrame({"Car make":series,"Colour:":colours})
car_data
# Out:
#   Car make Colour:
# 0      BMW     Red
# 1   Toyota    Blue
# 2    Honda   Green

# %% [markdown]
# # A6 Importing data into a df

# %%
car_data = pd.read_csv("car-sales.csv")
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ![obraz.png](attachment:f631c19e-79ec-4c72-8bf4-3411daad91de.png)

# %% [markdown]
# # A7 Exporting to csv:

# %%
car_data.to_csv("export_car_sales_v1.csv")

# %%
exported_car_sales = pd.read_csv("export_car_sales_v1.csv")
exported_car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # A8 ommitting the index:

# %%
car_data.to_csv("export_car_sales_v1.csv",index = False)

# %%
exported_car_sales = pd.read_csv("export_car_sales_v1.csv")
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # A9 Downloading from URL

# %%
heart_disease = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv")

# %%
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# # __Describing data with Pandas__

# %% [markdown]
# # dtypes is an attr

# %%
car_data.dtypes
# Out:
# Make               str
# Colour             str
# Odometer (KM)    int64
# Doors            int64
# Price              str
# dtype: object

# %%
car_data.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='str')

# %%
car_columns = car_data.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='str')

# %%
car_data.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %% [markdown]
# # A5 describe()  method:

# %%
car_data.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %% [markdown]
# # A6 info() function :

# %%
car_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     str
#  1   Colour         10 non-null     str
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     str
# dtypes: int64(2), str(3)
# memory usage: 532.0 bytes

# %% [markdown]
# # A7 mean() function :

# %%
car_data.mean(numeric_only=True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
#car_data.mean()

# %% [markdown]
# # A8 mean on pd.series

# %%
car_prices = pd.Series([3000,1500,111200])
car_prices = float(car_prices.mean())
car_prices
# Out:
# 38566.666666666664

# %% [markdown]
# # A9 sum()

# %%
car_prices.sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 car_prices.sum()
#
# AttributeError: 'float' object has no attribute 'sum'

# %%
car_data.sum()

# %% [markdown]
# # A10 per column operations:

# %%
car_data["Doors"].sum()

# %%
float(car_data["Doors"].sum())

# %% [markdown]
# # __55. Selecting and viewing data with Pandas__

# %% [markdown]
# # Viewing and selecting data

# %%
car_data.head()

# %% [markdown]
# # A2 tail():

# %%
car_data.tail()

# %% [markdown]
# # A3 loc and .iloc

# %%
animals = pd.Series(["dog","cat","moose","capybara","snake"],index=[0,3,9,7,3])

# %%
animals

# %%
animals.loc[3] # shows all items with a forced index of 3

# %%
car_data.loc[3]

# %% [markdown]
# # A5 .iloc()

# %%
animals.iloc[3]

# %%
car_data.iloc[3]

# %%
car_data[3]

# %%
animals.loc[:2]

# %%
animals.iloc[:4]

# %% [markdown]
# # A6 column:

# %%
car_data["Make"]

# %% [markdown]
# ##  second method:

# %%
car_data.

# %%
Make

# %% [markdown]
# # A8 Filtering columns:

# %%
car_data["Make"] == "Toyota"

# %%
car_data[car_data["Make"] == "Toyota"]

# %%
car_data[car_data["Odometer (KM)"] > 100000]

# %% [markdown]
# # __Selecting and Viewing Data with Pandas Part 2__

# %% [markdown]
# # A1 crosstab

# %%
pd.crosstab(car_data["Make"],car_data["Doors"])

# %% [markdown]
# # A2 groupby()

# %%
car_data.groupby(["Make"]).mean(numeric_only=True)

# %% [markdown]
# # A3 plot

# %%
car_data["Odometer (KM)"].plot()

# %% [markdown]
# # A4 histogram:

# %%
car_data["Odometer (KM)"].hist()

# %% [markdown]
# # A5 Regex string to int conversion:

# %%
car_data["Price"] = car_data["Price"].str.replace('[\\$\\,\\.]','',regex=True).astype(int)

# %%
car_data["Price"]=car_data["Price"]/100

# %%
car_data

# %% [markdown]
# # __Manipulating Data__

# %% [markdown]
# # A1 lower:

# %% [markdown]
# anything you can do on strings in python you can do on string colu mns in Pandas

# %%
car_data["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: str

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # A2 reqassigning the column:

# %%
car_data["Make"] = car_data["Make"].str.lower()

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  toyota  White         150043      4   $4,000.00
# 1   honda    Red          87899      4   $5,000.00
# 2  toyota   Blue          32549      3   $7,000.00
# 3     bmw  Black          11179      5  $22,000.00
# 4  nissan  White         213095      4   $3,500.00
# 5  toyota  Green          99213      4   $4,500.00
# 6   honda   Blue          45698      4   $7,500.00
# 7   honda   Blue          54738      4   $7,000.00
# 8  toyota  White          60000      4   $6,250.00
# 9  nissan  White          31600      4   $9,700.00

# %% [markdown]
# # A3 inplace parameter :

# %% [markdown]
# # A4 car_sales missing

# %%
car_data_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
car_data_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %% [markdown]
# # A5 fillna()

# %%
car_data_missing["Odometer"].fillna(car_data_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %% [markdown]
# # A6 inplace

# %%
car_data_missing["Odometer"].fillna(car_data_missing["Odometer"].mean(), inplace = True)
# Out:
# C:\Users\Nouser\AppData\Local\Temp\ipykernel_412\1274511994.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   car_data_missing["Odometer"].fillna(car_data_missing["Odometer"].mean(), inplace = True)
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# ...

# %%
car_data_missing.fillna({"Odometer":car_data_missing["Odometer"].mean()}, inplace = True)
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_data_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %% [markdown]
# # A7 dropna
# ## inplace

# %%
car_data_missing.dropna(inplace=True)

# %%
car_data_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %% [markdown]
# # A8 copy with dropna

# %%
car_data_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
car_data_missing_nan = car_data_missing.dropna()

# %%
car_data_missing_nan
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_data_missing_nan.to_csv("car_data_missing_nan.csv")
