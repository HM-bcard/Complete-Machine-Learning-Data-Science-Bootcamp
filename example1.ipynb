# %% [markdown]
# # Hello World

# %%
print("this is the first time using jn in this env")
# Out:
# this is the first time using jn in this env

# %%
a = 5

# %%
a = 3

# %% [markdown]
#  # A1 : cell numbers show the order at which the cells were ran in

# %% [markdown]
# # Heart disease project

# %% [markdown]
# # A2 :

# %% [markdown]
# # m for markdown y for code

# %% [markdown]
# # esc in general to enter command mode

# %% [markdown]
# #  Heart disease project
#
# ## This project is to create a classification whether or not the patient has heart disease

# %% [markdown]
# # A3 Importing pandas

# %%
import pandas as pd

# %% [markdown]
# # A4 downloading the data into a dataframe

# %%
df = pd.read_csv('heart-disease.csv')

# %% [markdown]
# # A5 viewing data in pandas:

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# # The following table shows heart disease information for patients:

# %%
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# ...

# %% [markdown]
# # A6 creating a bar graph:

# %%
df.target.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='target'>

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # A7 Robustness of tools:

# %% [markdown]
# you can do your entire project in the notebook

# %% [markdown]
# ![](6-step-ml-framework.png)

# %% [markdown]
# # markdown syntax for importing an image syntax:

# %%
"y ![](6-step-ml-framework.png)"
# Out:
# 'y ![](6-step-ml-framework.png)'

# %% [markdown]
# # framework according to the template:

# %% [markdown]
# ## **1. Problem definition:**

# %% [markdown]
# Predict heart disease

# %% [markdown]
# # __2.Data:__

# %% [markdown]
# This is the data we will be using

# %% [markdown]
# # A8

# %% [markdown]
# running terminal commands from jupyter notebooks

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is BAAB-09F8
#
#  Directory of C:\Users\Nouser\Desktop\ML\Complete Machine Learning and Data Science Bootcamp\sample_project1
#
# 04/09/2026  01:57 AM    <DIR>          .
# 04/09/2026  01:19 AM    <DIR>          ..
# 04/09/2026  01:25 AM    <DIR>          .ipynb_checkpoints
# 04/09/2026  01:19 AM           332,025 6-step-ml-framework.png
# 04/07/2026  11:34 PM    <DIR>          env
# 04/08/2026  11:32 PM               231 environment.yml
# 04/09/2026  01:57 AM            31,949 example1.ipynb
# 04/09/2026  01:20 AM            11,328 heart-disease.csv
# 04/07/2026  11:46 PM             1,496 one.1.ipynb
#                5 File(s)        377,029 bytes
#                4 Dir(s)  79,941,394,432 bytes free

# %%
dir
# Out:
# <function dir>
